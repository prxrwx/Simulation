# %% [markdown]
# <a href="https://colab.research.google.com/github/prxrwx/Simulation/blob/main/Example-queue-simulate3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import simpy
import random

# %% [markdown]
# SimPy in Queuing simulation for non-linear

# %%
# Arrivals generator function
def patient_generator_ed(env, ed_inter, mean_regis, mean_triage,
                         mean_ed_assess, mean_acu_assess,
                         receptionist, nurse, ed_doctor, acu_doctor):
  p_id = 0

  while True:
    # Create new instance of activity_generator
    p = activity_generator_ed(env, mean_regis, mean_triage, 
                              mean_ed_assess, mean_acu_assess,
                              receptionist, nurse, ed_doctor, acu_doctor, p_id)
    # Run the activity generator
    env.process(p)

    # Sample time to next arrival
    t = random.expovariate(1.0/ed_inter)
    
    # Freeze until time elapsed
    yield env.timeout(t)

    p_id += 1

# %%
# Activity generator function
def activity_generator_ed(env, mean_regis, mean_triage, 
                          mean_ed_assess, mean_acu_assess,
                          receptionist, nurse, ed_doctor, acu_doctor, p_id):
  time_enqueue_of_registration = env.now

  # Request a receptionist
  with receptionist.request() as req:
    # Freeze until the request can be met
    yield req

    time_dequeue_of_registration = env.now
    time_in_queue_for_registration = (time_dequeue_of_registration - 
                                      time_enqueue_of_registration)
    
    print("Patient ",p_id, " queued for registration for ", 
          time_in_queue_for_registration, " minutes.",sep="")
    # Sample the time spent in registration
    sampled_registration_time = random.expovariate(1.0/mean_regis)

    # Freeze until that time has elapsed
    yield env.timeout(sampled_registration_time)

# The above with statement, assign with the receptionist. 
# Now start for queuing of the nurse.
  time_enqueue_of_nurse = env.now

  # Request a nurse
  with nurse.request() as req:
    # Freeze until the request can be met
    yield req

    # Calculate time patient was queuing
    time_dequeue_of_nurse = env.now
    time_in_queue_for_nurse = (time_dequeue_of_nurse -
                               time_enqueue_of_nurse)
    print("Patient " , p_id, " queued for triage for ", 
          time_in_queue_for_nurse, " minutes.", sep="")
    # Sample time spent with nurse
    sampled_triage_time = random.expovariate(1.0/mean_triage)

    # Freeze until that time has passed
    yield env.timeout(sampled_triage_time)     

    # Branching path for ACU or ED 
    # We split them out using percentages probabilities, so let's randomly
    # sample from a uniform distribution to decide ACU or ED          
    decide_acu_branch = random.uniform(0,1)             
    if decide_acu_branch < 0.2:
      time_enqueue_of_acu_assess = env.now

      # Request an ACU doctor
      with acu_doctor.request() as req:
        # Freeze until the request can be met
        yield req

        time_dequeue_of_acu_assess = env.now
        time_in_queue_for_acu_assess = (time_dequeue_of_acu_assess -
                                        time_enqueue_of_acu_assess)
        print("Patient ",p_id, " queued for ACU assessment for ",
              time_in_queue_for_acu_assess, " minutes.", sep="")
        # Sample the time spend being assessed by the ACU doctor
        sampled_acu_assess_time = random.expovariate(1.0/mean_acu_assess)
        # Freeze until that time has elapsed
        yield env.timeout(sampled_acu_assess_time)
    else:
      time_enqueue_of_ed_assess = env.now
      # Request an ED doctor
      with ed_doctor.request() as req:
        # Freeze until the request can be met
        yield req
        
        time_dequeue_of_ed_assess = env.now
        time_in_queue_for_ed_assess = (time_dequeue_of_ed_assess -
                                       time_enqueue_of_ed_assess)
        print("Patient ",p_id, " queued for ED assessment for ",
              time_in_queue_for_ed_assess, " minutes.", sep="")

# %%
# Set up simulation environment
env = simpy.Environment()

# Set up resources
receptionist = simpy.Resource(env, capacity=1)
nurse = simpy.Resource(env, capacity=2)
ed_doctor = simpy.Resource(env, capacity=2)
acu_doctor = simpy.Resource(env, capacity=1)

# Set up parameter values
ed_inter = 8
mean_regis = 2
mean_triage = 5
mean_ed_assess = 30
mean_acu_assess = 60

# Start the arrivals generator
env.process(patient_generator_ed(env, ed_inter, mean_regis, mean_triage,
                                 mean_ed_assess, mean_acu_assess, 
                                 receptionist, nurse, ed_doctor, acu_doctor))

# Run the simulation
env.run(until=400)
# Out:
# Patient 0 queued for registration for 0 minutes.
# Patient 0 queued for triage for 0.0 minutes.
# Patient 1 queued for registration for 2.796356302718619 minutes.
# Patient 1 queued for triage for 0.0 minutes.
# Patient 2 queued for registration for 1.9388538069013728 minutes.
# Patient 0 queued for ED assessment for 0.0 minutes.
# Patient 2 queued for triage for 0.0 minutes.
# Patient 3 queued for registration for 0.8307287666889005 minutes.
# Patient 1 queued for ACU assessment for 0.0 minutes.
# Patient 2 queued for ED assessment for 0.0 minutes.
# Patient 3 queued for triage for 4.645954561701673 minutes.
# Patient 4 queued for registration for 0.0 minutes.
# Patient 3 queued for ED assessment for 0.0 minutes.
# Patient 4 queued for triage for 2.7034159953343 minutes.
# Patient 4 queued for ED assessment for 0.0 minutes.
# Patient 5 queued for registration for 0.0 minutes.
# Patient 5 queued for triage for 0.0 minutes.
# Patient 6 queued for registration for 0.0 minutes.
# Patient 5 queued for ED assessment for 0.0 minutes.
# Patient 6 queued for triage for 2.6205706855182207 minutes.
# Patient 6 queued for ED assessment for 0.0 minutes.
# Patient 7 queued for registration for 0.0 minutes.
# Patient 7 queued for triage for 0.0 minutes.
# Patient 8 queued for registration for 0.0 minutes.
# Patient 7 queued for ED assessment for 0.0 minutes.
# Patient 8 queued for triage for 2.9089293697427223 minutes.
# Patient 9 queued for registration for 0.0 minutes.
# Patient 9 queued for triage for 0.0 minutes.
# Patient 10 queued for registration for 0.0 minutes.
# Patient 8 queued for ACU assessment for 0.0 minutes.
# Patient 9 queued for ED assessment for 0.0 minutes.
# Patient 10 queued for triage for 3.49185642548413 minutes.
# Patient 10 queued for ED assessment for 0.0 minutes.
# Patient 11 queued for registration for 0.0 minutes.
# Patient 11 queued for triage for 0.0 minutes.
# Patient 11 queued for ED assessment for 0.0 minutes.
# Patient 12 queued for registration for 0.0 minutes.
# Patient 12 queued for triage for 0.0 minutes.
# Patient 13 queued for registration for 0.0 minutes.
# Patient 13 queued for triage for 0.0 minutes.
# Patient 12 queued for ED assessment for 0.0 minutes.
# Patient 14 queued for registration for 0.0 minutes.
# Patient 14 queued for triage for 0.0 minutes.
# Patient 15 queued for registration for 0.0 minutes.
# Patient 13 queued for ED assessment for 0.0 minutes.
# Patient 15 queued for triage for 0.0 minutes.
# Patient 16 queued for registration for 0.6881778413566053 minutes.
# Patient 14 queued for ED assessment for 0.0 minutes.
# Patient 15 queued for ED assessment for 0.0 minutes.
# Patient 16 queued for triage for 0.0 minutes.
# Patient 17 queued for registration for 1.5091401549626084 minutes.
# Patient 17 queued for triage for 0.0 minutes.
# Patient 16 queued for ACU assessment for 0.0 minutes.
# Patient 18 queued for registration for 0.0 minutes.
# Patient 19 queued for registration for 1.9269473800463572 minutes.
# Patient 20 queued for registration for 2.1655845532993396 minutes.
# Patient 21 queued for registration for 7.673862124224229 minutes.
# Patient 17 queued for ED assessment for 0.0 minutes.
# Patient 18 queued for triage for 7.841993241602182 minutes.
# Patient 18 queued for ED assessment for 0.0 minutes.
# Patient 19 queued for triage for 11.730019904966582 minutes.
# Patient 22 queued for registration for 14.529121069459364 minutes.
# Patient 20 queued for triage for 10.321393343216869 minutes.
# Patient 23 queued for registration for 1.8917520344657248 minutes.
# Patient 20 queued for ACU assessment for 0.0 minutes.
# Patient 24 queued for registration for 0.0 minutes.
# Patient 19 queued for ACU assessment for 7.749951095777874 minutes.
# Patient 21 queued for triage for 18.51843640182392 minutes.
# Patient 25 queued for registration for 0.0 minutes.
# Patient 26 queued for registration for 0.0 minutes.
# Patient 27 queued for registration for 0.0 minutes.
# Patient 28 queued for registration for 3.2002325678072907 minutes.
# Patient 29 queued for registration for 0.0 minutes.
# Patient 30 queued for registration for 0.0 minutes.
# Patient 31 queued for registration for 0.0 minutes.
# Patient 21 queued for ACU assessment for 58.385546838007 minutes.
# Patient 22 queued for triage for 75.38651013217762 minutes.
# Patient 32 queued for registration for 0.0 minutes.
# Patient 22 queued for ED assessment for 0.0 minutes.
# Patient 23 queued for triage for 76.85278507283931 minutes.
# Patient 33 queued for registration for 0.0 minutes.
# Patient 34 queued for registration for 0.0 minutes.
# Patient 35 queued for registration for 1.629247656440299 minutes.
# Patient 23 queued for ACU assessment for 18.85803079713918 minutes.
# Patient 24 queued for triage for 89.4503959839254 minutes.
# Patient 24 queued for ED assessment for 0.0 minutes.
# Patient 25 queued for triage for 84.87115827984687 minutes.
# Patient 25 queued for ED assessment for 0.0 minutes.
# Patient 26 queued for triage for 74.19656286017374 minutes.
# Patient 26 queued for ED assessment for 0.0 minutes.
# Patient 27 queued for triage for 66.05848911871911 minutes.
# Patient 27 queued for ED assessment for 0.0 minutes.
# Patient 28 queued for triage for 66.64921947496134 minutes.
# Patient 36 queued for registration for 0.0 minutes.
# Patient 28 queued for ED assessment for 0.0 minutes.
# Patient 29 queued for triage for 52.13040177727041 minutes.
# Patient 37 queued for registration for 0.0 minutes.
# Patient 29 queued for ED assessment for 0.0 minutes.
# Patient 30 queued for triage for 53.529332104270765 minutes.
# Patient 30 queued for ED assessment for 0.0 minutes.
# Patient 31 queued for triage for 53.633700870135215 minutes.
# Patient 31 queued for ED assessment for 0.0 minutes.
# Patient 32 queued for triage for 45.973882448677074 minutes.
# Patient 32 queued for ED assessment for 0.0 minutes.
# Patient 33 queued for triage for 32.37229783562333 minutes.
# Patient 38 queued for registration for 0.0 minutes.
# Patient 39 queued for registration for 0.0 minutes.
# Patient 40 queued for registration for 0.0 minutes.
# Patient 41 queued for registration for 0.0 minutes.
# Patient 42 queued for registration for 0.0 minutes.
# Patient 43 queued for registration for 0.0 minutes.
# Patient 44 queued for registration for 0.0 minutes.
# Patient 45 queued for registration for 0.0 minutes.
# Patient 46 queued for registration for 0.0 minutes.
# Patient 47 queued for registration for 0.0 minutes.
# Patient 48 queued for registration for 0.0 minutes.
# Patient 49 queued for registration for 0.0 minutes.
# Patient 50 queued for registration for 0.0 minutes.
# Patient 33 queued for ACU assessment for 82.08953781413572 minutes.
# Patient 34 queued for triage for 111.62829518062861 minutes.
# Patient 34 queued for ED assessment for 0.0 minutes.
# Patient 35 queued for triage for 108.76844165030712 minutes.
# Patient 51 queued for registration for 0.0 minutes.
# Patient 52 queued for registration for 3.0505016418204036 minutes.
